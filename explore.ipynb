# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import arrow

# %%
gas  = pd.read_csv('mpg.csv', skipinitialspace=True)
print(gas.head())
gas['Date'] = gas['Date'].apply(lambda x: arrow.get(x))
oil  = pd.read_csv('oil.csv', skipinitialspace=True)
tire = pd.read_csv('tires.csv', skipinitialspace=True)
registration = pd.read_csv('registration.csv', skipinitialspace=True)
# Out:
#          Date    Latitude      Longitude        Brand  Pump  AKI  Trip Miles  \
# 0  2013-11-03  40° 1.729'  -105° 15.516'  Boulder Gas   2.0   87       134.3
# 1  2013-11-17  40° 1.729'  -105° 15.516'  Boulder Gas   2.0   87       161.8
# 2  2013-11-27  40° 0.872'  -105° 12.775'  Buffalo Gas   6.0   87       180.8
# 3  2013-12-07  40° 1.729'  -105° 15.516'  Boulder Gas   6.0   87       265.1
# 4  2013-12-11  40° 2.170'  -105° 15.522'     Circle K   4.0   87       240.9
#
#    Total Miles  Gallons    MPG    PPG  Total  Tires  MPG-D  MPH-D Service
# 0        134.3    6.563  20.46  3.319  21.78  Stock    NaN    NaN      S0
# 1        296.0    7.467  21.67  3.279  24.48  Stock    NaN    NaN      S0
# 2        477.0    8.096  22.33  3.359  27.19  Stock    NaN    NaN      S0
# 3        742.0   12.073  21.96  3.179  38.38  Stock    NaN    NaN      S0
# 4        983.0    9.868  24.41  3.179  31.37  Stock    NaN    NaN      S0

# %%
print("Gas:\t\t{}".format(str(gas['Total'].sum())))
print("Oil:\t\t{}".format(str(oil['Total'].sum())))
print("Tires:\t\t{}".format(str(tire['Total'].sum())))
print("Registration:\t{}".format(str(registration['Total'].sum())))

print("Sum:\t\t{}".format(str(gas['Total'].sum()+oil['Total'].sum()+tire['Total'].sum()+registration['Total'].sum())))
# Out:
# Gas:		4322.229999999998
# Oil:		932.7400000000001
# Tires:		1077.33
# Registration:	1291.8400000000001
# Sum:		7624.139999999998

# %%
gas.groupby(['Service']).mean()
# Out:
#              Pump        AKI  Trip Miles   Total Miles    Gallons        MPG  \
# Service
# S0       4.368421  87.000000  178.305263   1805.068421   7.936737  22.353684
# S1       5.176471  87.058824  244.676471   5619.470588   8.695588  28.600588
# S2       4.692308  87.000000  210.996154  10698.846154   7.761077  27.045000
# S3       5.071429  87.000000  299.371429  17318.178571  10.026714  29.668929
# S4       4.600000  85.222222  305.666667  26044.703704  10.406259  29.327407
# S5       6.545455  85.000000  317.768182  33638.227273  11.031136  28.845000
# S6       4.826087  85.000000  293.686957  40649.000000  10.339148  28.185217
# S7       6.538462  85.000000  269.261538  45616.769231   9.992923  26.865385
#
#               PPG      Total      MPG-D      MPH-D
# Service
# S0       3.363211  26.579474  24.625000        NaN
# S1       3.708412  32.271176  30.676471  33.812500
# S2       3.180115  25.543077  29.319231  26.384615
# S3       2.554000  25.785714  32.014286  31.392857
# S4       2.226037  23.262963  31.855556  31.333333
# S5       1.989000  21.718182  31.404545  28.909091
# S6       2.056826  21.259565  30.860870  27.478261
# S7       2.215923  22.124615  29.123077  24.076923

# %%
gas.groupby(['Service']).sum()
# Out:
#           Pump   AKI  Trip Miles  Total Miles   Gallons     MPG     PPG  \
# Service
# S0        83.0  1653      3387.8      34296.3  150.7980  424.72  63.901
# S1        88.0  1480      4159.5      95531.0  147.8250  486.21  63.043
# S2       122.0  2262      5485.9     278170.0  201.7880  703.17  82.683
# S3       142.0  2436      8382.4     484909.0  280.7480  830.73  71.512
# S4       115.0  2301      8253.0     703207.0  280.9690  791.84  60.103
# S5       144.0  1870      6990.9     740041.0  242.6850  634.59  43.758
# S6       111.0  1955      6754.8     934927.0  237.8004  648.26  47.307
# S7        85.0  1105      3500.4     593018.0  129.9080  349.25  28.807
#
#           Total  MPG-D  MPH-D
# Service
# S0       505.01  295.5    NaN
# S1       548.61  521.5  541.0
# S2       664.12  762.3  686.0
# S3       722.00  896.4  879.0
# S4       628.10  860.1  846.0
# S5       477.80  690.9  636.0
# S6       488.97  709.8  632.0
# S7       287.62  378.6  313.0

# %%
gas.plot(x="Date", y="Total Miles",figsize=(10,8))

# %%
gas.plot(x="Date", y="Trip Miles",figsize=(10,8))

# %%
gas.plot(x="Date", y="PPG",figsize=(10,8))

# %%
gas.plot(x="Date", y="MPH-D",figsize=(10,8))

# %%
gas.plot(x="Date", y="MPG",figsize=(10,8))

# %%
gas.plot(x="MPH-D",y="MPG-D", kind="scatter",figsize=(10,8))

# %%
gas.plot(x="MPH-D",y="MPG", kind="scatter",figsize=(10,8))

# %%
gas.plot(x="MPG-D",y="MPG", kind="scatter",figsize=(10,8))

# %%
from sklearn import linear_model
